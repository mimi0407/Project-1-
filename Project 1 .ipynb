# %%
import pandas as pd
location = "Untitled Folder/DC_Properties.csv"
df = pd.read_csv(location)
df.head ()
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# 0  1910.0   1988.0   ...    -77.040832       Old City 2   040 D Old City 2
# 1  1898.0   2007.0   ...    -77.040764       Old City 2   040 D Old City 2
# 2  1910.0   2009.0   ...    -77.040678       Old City 2   040 D Old City 2
# 3  1900.0   2003.0   ...    -77.040629       Old City 2   040 D Old City 2
# 4  1913.0   2012.0   ...    -77.039361       Old City 2   040 D Old City 2
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df['BEDRM'].max
# Out:
# <bound method Series.max of 0         4
# 1         5
# 2         5
# 3         5
# 4         3
# 5         5
# 6         2
# 7         4
# 8         3
# 9         2
# 10        5
# 11        6
# 12        5
# 13        5
# 14        3
# 15        4
# 16        3
# 17        3
# 18        4
# 19        3
# 20        5
# 21        3
# 22        3
# 23        3
# 24        3
# 25        4
# 26        5
# 27        3
# 28        4
# 29        3
#          ..
# 158927    3
# 158928    2
# 158929    2
# 158930    2
# 158931    2
# 158932    2
# 158933    2
# 158934    1
# 158935    1
# 158936    1
# 158937    2
# 158938    4
# 158939    2
# 158940    4
# 158941    2
# 158942    4
# 158943    2
# 158944    2
# 158945    1
# 158946    2
# 158947    2
# 158948    2
# 158949    1
# 158950    3
# 158951    3
# 158952    1
# 158953    2
# 158954    2
# 158955    0
# 158956    0
# Name: BEDRM, Length: 158957, dtype: int64>

# %%
df['PRICE'].sum
# Out:
# <bound method Series.sum of 0         1095000.0
# 1               NaN
# 2         2100000.0
# 3         1602000.0
# 4               NaN
# 5         1950000.0
# 6               NaN
# 7         1050000.0
# 8         1430000.0
# 9               NaN
# 10              NaN
# 11              NaN
# 12              NaN
# 13              NaN
# 14        1325000.0
# 15              NaN
# 16        1240000.0
# 17              NaN
# 18              NaN
# 19         592250.0
# 20          33232.0
# 21              NaN
# 22         907400.0
# 23        1065000.0
# 24        1100000.0
# 25          20000.0
# 26              NaN
# 27         703700.0
# 28              NaN
# 29        1210000.0
#             ...
# 158927          NaN
# 158928     632400.0
# 158929     574000.0
# 158930     365000.0
# 158931     405000.0
# 158932     505000.0
# 158933     520000.0
# 158934     499900.0
# 158935     451000.0
# 158936     564900.0
# 158937          NaN
# 158938     660000.0
# 158939     380000.0
# ...

# %%
df.sort_values ('PRICE')
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM            HEAT AC  NUM_UNITS  ROOMS  \
# 132821      132821       2          0      Forced Air  Y        NaN      4
# 148694      148694       1          0      Forced Air  Y        NaN      3
# 152131      152131       2          0   Hot Water Rad  N        NaN      6
# 81694        81694       1          1   Hot Water Rad  N        1.0      7
# 106683      106683       3          0      Forced Air  N        3.0     14
# 18568        18568       2          1   Hot Water Rad  N        2.0      8
# 74419        74419       2          0   Hot Water Rad  N        1.0      8
# 81594        81594       1          0   Hot Water Rad  N        1.0      5
# 51658        51658       1          0   Hot Water Rad  N        1.0      6
# 48414        48414       2          0      Forced Air  N        1.0      8
# 14041        14041       2          0   Hot Water Rad  Y        1.0      6
# ...

# %%
df['PRICE'] < 100000
#there was 2 prices that were below $100000
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20         True
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df['BEDRM']==3
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8          True
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14         True
# 15        False
# 16         True
# 17         True
# 18        False
# 19         True
# 20        False
# 21         True
# 22         True
# 23         True
# 24         True
# 25        False
# 26        False
# 27         True
# 28        False
# 29         True
#           ...
# 158927     True
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950     True
# ...

# %%
(df['BEDRM']==3) & (df['PRICE'] < 100000)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
(df['PRICE']<100000) & (df['ASSESSMENT_NBHD'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20         True
# 21        False
# 22        False
# 23        False
# 24        False
# 25         True
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927    False
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
(df['BEDRM']==3) & (df['BATHRM']==2)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
# 5         False
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17         True
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23         True
# 24         True
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 158927     True
# 158928    False
# 158929    False
# 158930    False
# 158931    False
# 158932    False
# 158933    False
# 158934    False
# 158935    False
# 158936    False
# 158937    False
# 158938    False
# 158939    False
# 158940    False
# 158941    False
# 158942    False
# 158943    False
# 158944    False
# 158945    False
# 158946    False
# 158947    False
# 158948    False
# 158949    False
# 158950    False
# ...

# %%
df[(df['BEDRM']==3) & (df['BATHRM']==2)]
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  \
# 4                4       2          1      Warm Cool  Y        1.0     11
# 17              17       2          0  Hot Water Rad  N        1.0      6
# 23              23       2          1     Forced Air  Y        1.0      5
# 24              24       2          1  Hot Water Rad  Y        1.0      8
# 30              30       2          1     Forced Air  Y        2.0      8
# 33              33       2          1     Forced Air  Y        2.0     10
# 48              48       2          1     Forced Air  N        2.0      8
# 50              50       2          1     Forced Air  Y        2.0      8
# 64              64       2          2  Hot Water Rad  Y        1.0      8
# 71              71       2          0      Warm Cool  Y        2.0      6
# 75              75       2          1      Warm Cool  Y        2.0     11
# 77              77       2          1      Warm Cool  Y        2.0     11
# ...

# %%
df[(df['BEDRM']==3) & (df['BATHRM']==2)].mean()
# Out:
# Unnamed: 0       61747.485992
# BATHRM               2.000000
# HF_BATHRM            0.633293
# NUM_UNITS            1.076418
# ROOMS                6.679721
# BEDRM                3.000000
# AYB               1942.864760
# YR_RMDL           2001.387299
# EYB               1969.327168
# STORIES              2.057678
# PRICE           503192.165296
# SALE_NUM             1.652749
# GBA               1533.536164
# BLDG_NUM             1.000209
# KITCHENS             1.087956
# FIREPLACES           0.566824
# USECODE             12.776502
# LANDAREA          2973.902969
# CMPLX_NUM         2759.375057
# LIVING_GBA        1536.162631
# ZIPCODE          20012.839005
# LATITUDE            38.915623
# LONGITUDE          -77.008744
# CENSUS_TRACT      5661.897040
# X                  -77.008782
# Y                   38.915638
# dtype: float64

# %%
df[(df['BEDRM']==3) & (df['PRICE'] < 100000)].mean()
# Out:
# Unnamed: 0      75183.651106
# BATHRM              1.318182
# HF_BATHRM           0.374693
# NUM_UNITS           1.053514
# ROOMS               6.324324
# BEDRM               3.000000
# AYB              1935.387415
# YR_RMDL          1994.979866
# EYB              1958.441032
# STORIES             1.975822
# PRICE           74355.815111
# SALE_NUM            1.092138
# GBA              1288.836235
# BLDG_NUM            1.000000
# KITCHENS            1.056738
# FIREPLACES          0.140049
# USECODE            12.292383
# LANDAREA         2448.398649
# CMPLX_NUM        1795.909091
# LIVING_GBA       1159.454545
# ZIPCODE         20014.484644
# LATITUDE           38.896953
# LONGITUDE         -76.983590
# CENSUS_TRACT     7342.216830
# X                 -76.983575
# Y                  38.896998
# dtype: float64

# %%
#I have found that the DC area is very expensive to live in. 
#It is a good neighborhood but yor choices for a house under a $100000 is very slim. 
#The more aspects you look for in a house (e.g. more bedrooms or a fire place) the more you are going to pay
